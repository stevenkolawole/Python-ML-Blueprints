# %% [markdown]
# ## Setup

# %% [markdown]
# - The OS library is used for interacting with the Operating System's files and directories
# - Python Requests Library, also known as HTTP for humans, provide a clean and fast way to interact with APIs.
# - Numerical Python library, NumPy for short, is used to perform numerical operations on data.
# - Built on NumPy, Pandas is an excellent tool for Data Analysis.

# %%
import os
import requests
import numpy as np
import pandas as pd

# %% [markdown]
# ## Data Acquisition

# %%
# check the current working directory
os.getcwd()
# Out:
# 'C:\\Users\\user-pc\\Downloads\\Projects\\Python ML Blueprints\\1.-Baby-Steps-into-Data-Analysis-and-Machine-Learning'

# %%
# Getting the CSV file
PATH = 'C:\\Users\\user-pc\\Downloads\\Projects\\Python ML Blueprints\\1.-Baby-Steps-into-Data-Analysis-and-Machine-Learning'

r = requests.get('https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data')

# %%
# Writing the data into a local file.
with open(PATH + '/iris.data', 'w') as f:
    f.write(r.text)

# %%
df = pd.read_csv("iris.data", 
                 names=['sepal length', 'sepal width', 'petal length', 'petal width', 'class'])
df.head()
# Out:
#    sepal length  sepal width  petal length  petal width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# `loc` gets row (or columns) **with a particular label** from the index while `iloc` gets rows (or columns)  location **at particular positions** in the index (so it only takes integers)

# %%
df.loc[:3, [x for x in df.columns if 'width' in x]]
# Out:
#    sepal width  petal width
# 0          3.5          0.2
# 1          3.0          0.2
# 2          3.2          0.2
# 3          3.1          0.2

# %%
df.iloc[:3, :2]
# Out:
#    sepal length  sepal width
# 0           5.1          3.5
# 1           4.9          3.0
# 2           4.7          3.2

# %%
# Listing all the available unique classes

df['class'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
virginica = df[df['class'] == 'Iris-virginica'].count()
virginica
# Out:
# sepal length    50
# sepal width     50
# petal length    50
# petal width     50
# class           50
# dtype: int64

# %%
virginica = df[df['class'] == 'Iris-virginica'].reset_index(drop=True)
virginica
# Out:
#     sepal length  sepal width  petal length  petal width           class
# 0            6.3          3.3           6.0          2.5  Iris-virginica
# 1            5.8          2.7           5.1          1.9  Iris-virginica
# 2            7.1          3.0           5.9          2.1  Iris-virginica
# 3            6.3          2.9           5.6          1.8  Iris-virginica
# 4            6.5          3.0           5.8          2.2  Iris-virginica
# 5            7.6          3.0           6.6          2.1  Iris-virginica
# 6            4.9          2.5           4.5          1.7  Iris-virginica
# 7            7.3          2.9           6.3          1.8  Iris-virginica
# 8            6.7          2.5           5.8          1.8  Iris-virginica
# 9            7.2          3.6           6.1          2.5  Iris-virginica
# 10           6.5          3.2           5.1          2.0  Iris-virginica
# 11           6.4          2.7           5.3          1.9  Iris-virginica
# 12           6.8          3.0           5.5          2.1  Iris-virginica
# 13           5.7          2.5           5.0          2.0  Iris-virginica
# 14           5.8          2.8           5.1          2.4  Iris-virginica
# 15           6.4          3.2           5.3          2.3  Iris-virginica
# 16           6.5          3.0           5.5          1.8  Iris-virginica
# 17           7.7          3.8           6.7          2.2  Iris-virginica
# 18           7.7          2.6           6.9          2.3  Iris-virginica
# 19           6.0          2.2           5.0          1.5  Iris-virginica
# 20           6.9          3.2           5.7          2.3  Iris-virginica
# 21           5.6          2.8           4.9          2.0  Iris-virginica
# 22           7.7          2.8           6.7          2.0  Iris-virginica
# 23           6.3          2.7           4.9          1.8  Iris-virginica
# 24           6.7          3.3           5.7          2.1  Iris-virginica
# 25           7.2          3.2           6.0          1.8  Iris-virginica
# 26           6.2          2.8           4.8          1.8  Iris-virginica
# 27           6.1          3.0           4.9          1.8  Iris-virginica
# 28           6.4          2.8           5.6          2.1  Iris-virginica
# 29           7.2          3.0           5.8          1.6  Iris-virginica
# 30           7.4          2.8           6.1          1.9  Iris-virginica
# 31           7.9          3.8           6.4          2.0  Iris-virginica
# 32           6.4          2.8           5.6          2.2  Iris-virginica
# 33           6.3          2.8           5.1          1.5  Iris-virginica
# 34           6.1          2.6           5.6          1.4  Iris-virginica
# 35           7.7          3.0           6.1          2.3  Iris-virginica
# 36           6.3          3.4           5.6          2.4  Iris-virginica
# 37           6.4          3.1           5.5          1.8  Iris-virginica
# 38           6.0          3.0           4.8          1.8  Iris-virginica
# 39           6.9          3.1           5.4          2.1  Iris-virginica
# 40           6.7          3.1           5.6          2.4  Iris-virginica
# 41           6.9          3.1           5.1          2.3  Iris-virginica
# 42           5.8          2.7           5.1          1.9  Iris-virginica
# 43           6.8          3.2           5.9          2.3  Iris-virginica
# 44           6.7          3.3           5.7          2.5  Iris-virginica
# 45           6.7          3.0           5.2          2.3  Iris-virginica
# 46           6.3          2.5           5.0          1.9  Iris-virginica
# 47           6.5          3.0           5.2          2.0  Iris-virginica
# 48           6.2          3.4           5.4          2.3  Iris-virginica
# 49           5.9          3.0           5.1          1.8  Iris-virginica

# %%
df[(df['class'] == 'Iris-virginica') & (df['petal width'] > 2.2)]
# Out:
#      sepal length  sepal width  petal length  petal width           class
# 100           6.3          3.3           6.0          2.5  Iris-virginica
# 109           7.2          3.6           6.1          2.5  Iris-virginica
# 114           5.8          2.8           5.1          2.4  Iris-virginica
# 115           6.4          3.2           5.3          2.3  Iris-virginica
# 118           7.7          2.6           6.9          2.3  Iris-virginica
# 120           6.9          3.2           5.7          2.3  Iris-virginica
# 135           7.7          3.0           6.1          2.3  Iris-virginica
# 136           6.3          3.4           5.6          2.4  Iris-virginica
# 140           6.7          3.1           5.6          2.4  Iris-virginica
# 141           6.9          3.1           5.1          2.3  Iris-virginica
# 143           6.8          3.2           5.9          2.3  Iris-virginica
# 144           6.7          3.3           5.7          2.5  Iris-virginica
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica

# %%
#Getting some descriptive statistics of the dataset

df.describe()
# Out:
#        sepal length  sepal width  petal length  petal width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# Passing in custom percentiles

df.describe(percentiles=[.2, .4, .8, .9, .95])
# Out:
#        sepal length  sepal width  petal length  petal width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 20%        5.000000     2.700000      1.500000     0.200000
# 40%        5.600000     3.000000      3.900000     1.160000
# 50%        5.800000     3.000000      4.350000     1.300000
# 80%        6.520000     3.400000      5.320000     1.900000
# 90%        6.900000     3.610000      5.800000     2.200000
# 95%        7.255000     3.800000      6.100000     2.300000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# Checking for correlations between the features

df.corr()
# Out:
#               sepal length  sepal width  petal length  petal width
# sepal length      1.000000    -0.109369      0.871754     0.817954
# sepal width      -0.109369     1.000000     -0.420516    -0.356544
# petal length      0.871754    -0.420516      1.000000     0.962757
# petal width       0.817954    -0.356544      0.962757     1.000000

# %% [markdown]
# ## Visualization

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
# Plotting an histogram of the petal width feature

plt.figure(figsize=(6,4))
plt.hist(df['petal width'], color='black')
plt.xlabel('Width', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.title('Iris Petal Width', fontsize=14,)
# Out:
# Text(0.5, 1.0, 'Iris Petal Width')

# %%
# Plotting subplots of the 4 features (NOTE: THIS IS NOT IDEAL!)

fig, ax = plt.subplots(2, 2, figsize=(6,4))

ax[0][0].hist(df['petal width'], color='black')
ax[0][0].set_xlabel('Width', fontsize=12)
ax[0][0].set_ylabel('Count', fontsize=12)
ax[0][0].set_title("Iris Petal Width", fontsize=14)

ax[0][1].hist(df['petal length'], color='black')
ax[0][1].set_xlabel('Length', fontsize=12)
ax[0][1].set_ylabel('Count', fontsize=12)
ax[0][1].set_title("Iris Petal Length", fontsize=14)

ax[1][0].hist(df['sepal width'], color='black')
ax[1][0].set_xlabel('Width', fontsize=12)
ax[1][0].set_ylabel('Count', fontsize=12)
ax[1][0].set_title("Iris Sepal Width", fontsize=14)

ax[1][1].hist(df['sepal length'], color='black')
ax[1][1].set_xlabel('Length', fontsize=12)
ax[1][1].set_ylabel('Count', fontsize=12)
ax[1][1].set_title("Iris Sepal Length", fontsize=14)

plt.tight_layout()

# %%
# A scatterplot of the Petal Width against the Petal Length

plt.scatter(df['petal width'], df['petal length'], color='green')
plt.xlabel('Petal Width')
plt.ylabel('Petal Length')
plt.title('Petal Scatterplot')
# Out:
# Text(0.5, 1.0, 'Petal Scatterplot')

# %%
# A simple line plot of the Petal Length

plt.figure(figsize=(6,6))
plt.plot(df['petal length'], color='blue')
plt.xlabel('Specimen Number')
plt.ylabel('Petal Length')
plt.title('Petal Length Plot')
# Out:
# Text(0.5, 1.0, 'Petal Length Plot')

# %%
# A Bar-chart of the mean of each feature for the 3 classes of irises

fig, ax = plt.subplots(figsize=(6,6))
bar_width = .8
labels = [x for x in df.columns if 'length' in x or 'width' in x]

ver_y = [df[df['class'] == 'Iris-versicolor'][x].mean() for x in labels]
vir_y = [df[df['class'] == 'Iris-virginica'][x].mean() for x in labels]
set_y = [df[df['class'] == 'Iris-setosa'][x].mean() for x in labels]
x = np.arange(len(labels))

plt.bar(x, vir_y, bar_width, bottom=set_y, color='darkgrey')
plt.bar(x, set_y, bar_width, bottom=ver_y, color='white')
plt.bar(x, ver_y, bar_width, color='black')

plt.xticks(x)
ax.set_xticklabels(labels, rotation=-70, fontsize=12);
plt.title('Mean Measurement by Class')
plt.legend(['Virginica', 'Setosa', 'Versicolor'])

# %%
import seaborn as sns

sns.pairplot(df, hue='class')

# %%
sns.set(style='white', palette='muted')
y = ['sepal length', 'sepal width', 'petal length', 'petal width']

plt.figure(figsize=(7, 7))
for n in range(4):
    plt.subplot(2, 2, n+1)
    sns.violinplot(x='class', y=y[n], data=df)
    plt.xticks(rotation=90)
    
plt.suptitle('Violin Plots', fontsize=16)
plt.tight_layout()

# %% [markdown]
# ## Preparation
#
# Here we'd process and manipulate our data

# %% [markdown]
# ### Map

# %%
# Replacing each of the unique Iris types

dict_map = {'Iris-setosa': 'SET', 
            'Iris-virginica': 'VIR', 
            'Iris-versicolor': 'VER'}
df['class'] = df['class'].map(dict_map)
df
# Out:
#      sepal length  sepal width  petal length  petal width class
# 0             5.1          3.5           1.4          0.2   SET
# 1             4.9          3.0           1.4          0.2   SET
# 2             4.7          3.2           1.3          0.2   SET
# 3             4.6          3.1           1.5          0.2   SET
# 4             5.0          3.6           1.4          0.2   SET
# ..            ...          ...           ...          ...   ...
# 145           6.7          3.0           5.2          2.3   VIR
# 146           6.3          2.5           5.0          1.9   VIR
# 147           6.5          3.0           5.2          2.0   VIR
# 148           6.2          3.4           5.4          2.3   VIR
# 149           5.9          3.0           5.1          1.8   VIR
#
# [150 rows x 5 columns]

# %% [markdown]
# ### Apply
#
# Unlike `map`, `apply` works on both series (single columns) and dataframes (collections of series)

# %%
# Creating a new feature via petal width

df['wide petal'] = df['petal width'].apply(lambda x: 1 if x>=1.3 else 0)
df
# Out:
#      sepal length  sepal width  petal length  petal width class  wide petal
# 0             5.1          3.5           1.4          0.2   SET           0
# 1             4.9          3.0           1.4          0.2   SET           0
# 2             4.7          3.2           1.3          0.2   SET           0
# 3             4.6          3.1           1.5          0.2   SET           0
# 4             5.0          3.6           1.4          0.2   SET           0
# ..            ...          ...           ...          ...   ...         ...
# 145           6.7          3.0           5.2          2.3   VIR           1
# 146           6.3          2.5           5.0          1.9   VIR           1
# 147           6.5          3.0           5.2          2.0   VIR           1
# 148           6.2          3.4           5.4          2.3   VIR           1
# 149           5.9          3.0           5.1          1.8   VIR           1
#
# [150 rows x 6 columns]

# %%
# creating a new column via petal length & petal width

df['petal area'] = df.apply(lambda x: x['petal width'] * x['petal length'], axis=1)
df
# Out:
#      sepal length  sepal width  petal length  petal width class  wide petal  \
# 0             5.1          3.5           1.4          0.2   SET           0
# 1             4.9          3.0           1.4          0.2   SET           0
# 2             4.7          3.2           1.3          0.2   SET           0
# 3             4.6          3.1           1.5          0.2   SET           0
# 4             5.0          3.6           1.4          0.2   SET           0
# ..            ...          ...           ...          ...   ...         ...
# 145           6.7          3.0           5.2          2.3   VIR           1
# 146           6.3          2.5           5.0          1.9   VIR           1
# 147           6.5          3.0           5.2          2.0   VIR           1
# 148           6.2          3.4           5.4          2.3   VIR           1
# 149           5.9          3.0           5.1          1.8   VIR           1
#
#      petal area
# 0          0.28
# 1          0.28
# 2          0.26
# 3          0.30
# 4          0.28
# ..          ...
# 145       11.96
# 146        9.50
# 147       10.40
# 148       12.42
# 149        9.18
#
# [150 rows x 7 columns]

# %% [markdown]
# ### Applymap
#
# `applymap` only works on dataframes

# %%
# Getting the log values of all the data cells

df_ = df.applymap(lambda x: np.log(x) if isinstance(x, float) else x)
df_
# Out:
#      sepal length  sepal width  petal length  petal width class  wide petal  \
# 0        1.629241     1.252763      0.336472    -1.609438   SET           0
# 1        1.589235     1.098612      0.336472    -1.609438   SET           0
# 2        1.547563     1.163151      0.262364    -1.609438   SET           0
# 3        1.526056     1.131402      0.405465    -1.609438   SET           0
# 4        1.609438     1.280934      0.336472    -1.609438   SET           0
# ..            ...          ...           ...          ...   ...         ...
# 145      1.902108     1.098612      1.648659     0.832909   VIR           1
# 146      1.840550     0.916291      1.609438     0.641854   VIR           1
# 147      1.871802     1.098612      1.648659     0.693147   VIR           1
# 148      1.824549     1.223775      1.686399     0.832909   VIR           1
# 149      1.774952     1.098612      1.629241     0.587787   VIR           1
#
#      petal area
# 0     -1.272966
# 1     -1.272966
# 2     -1.347074
# 3     -1.203973
# 4     -1.272966
# ..          ...
# 145    2.481568
# 146    2.251292
# 147    2.341806
# 148    2.519308
# 149    2.217027
#
# [150 rows x 7 columns]

# %% [markdown]
# ### Groupby

# %%
df.groupby('class').mean()
# Out:
#        sepal length  sepal width  petal length  petal width  wide petal  \
# class
# SET           5.006        3.418         1.464        0.244         0.0
# VER           5.936        2.770         4.260        1.326         0.7
# VIR           6.588        2.974         5.552        2.026         1.0
#
#        petal area
# class
# SET        0.3628
# VER        5.7204
# VIR       11.2962

# %%
# T for transpose

df.groupby('class').describe().T
# Out:
# class                     SET        VER        VIR
# sepal length count  50.000000  50.000000  50.000000
#              mean    5.006000   5.936000   6.588000
#              std     0.352490   0.516171   0.635880
#              min     4.300000   4.900000   4.900000
#              25%     4.800000   5.600000   6.225000
#              50%     5.000000   5.900000   6.500000
#              75%     5.200000   6.300000   6.900000
#              max     5.800000   7.000000   7.900000
# sepal width  count  50.000000  50.000000  50.000000
#              mean    3.418000   2.770000   2.974000
#              std     0.381024   0.313798   0.322497
#              min     2.300000   2.000000   2.200000
#              25%     3.125000   2.525000   2.800000
#              50%     3.400000   2.800000   3.000000
#              75%     3.675000   3.000000   3.175000
#              max     4.400000   3.400000   3.800000
# petal length count  50.000000  50.000000  50.000000
#              mean    1.464000   4.260000   5.552000
#              std     0.173511   0.469911   0.551895
#              min     1.000000   3.000000   4.500000
#              25%     1.400000   4.000000   5.100000
#              50%     1.500000   4.350000   5.550000
#              75%     1.575000   4.600000   5.875000
#              max     1.900000   5.100000   6.900000
# petal width  count  50.000000  50.000000  50.000000
#              mean    0.244000   1.326000   2.026000
#              std     0.107210   0.197753   0.274650
#              min     0.100000   1.000000   1.400000
#              25%     0.200000   1.200000   1.800000
#              50%     0.200000   1.300000   2.000000
#              75%     0.300000   1.500000   2.300000
#              max     0.600000   1.800000   2.500000
# wide petal   count  50.000000  50.000000  50.000000
#              mean    0.000000   0.700000   1.000000
#              std     0.000000   0.462910   0.000000
#              min     0.000000   0.000000   1.000000
#              25%     0.000000   0.000000   1.000000
#              50%     0.000000   1.000000   1.000000
#              75%     0.000000   1.000000   1.000000
#              max     0.000000   1.000000   1.000000
# petal area   count  50.000000  50.000000  50.000000
#              mean    0.362800   5.720400  11.296200
#              std     0.183248   1.368403   2.157412
#              min     0.110000   3.300000   7.500000
#              25%     0.265000   4.860000   9.717500
#              50%     0.300000   5.615000  11.445000
#              75%     0.420000   6.750000  12.790000
#              max     0.960000   8.640000  15.870000

# %%
# Group the classes by the petal width they are associated with

df.groupby('petal width')['class'].unique().to_frame()
# Out:
#                   class
# petal width
# 0.1               [SET]
# 0.2               [SET]
# 0.3               [SET]
# 0.4               [SET]
# 0.5               [SET]
# 0.6               [SET]
# 1.0               [VER]
# 1.1               [VER]
# 1.2               [VER]
# 1.3               [VER]
# 1.4          [VER, VIR]
# 1.5          [VER, VIR]
# 1.6          [VER, VIR]
# 1.7          [VER, VIR]
# 1.8          [VER, VIR]
# 1.9               [VIR]
# 2.0               [VIR]
# 2.1               [VIR]
# 2.2               [VIR]
# 2.3               [VIR]
# 2.4               [VIR]
# 2.5               [VIR]

# %%
df.groupby('class')['petal width']\
.agg(delta=lambda x: x.max() - x.min(), min=np.min, max=np.max)
# Out:
#        delta  min  max
# class
# SET      0.5  0.1  0.6
# VER      0.8  1.0  1.8
# VIR      1.1  1.4  2.5

# %% [markdown]
# ## Modelling and Evaluation

# %% [markdown]
# ### Statsmodels

# %%
import statsmodels.api as sm

# %%
plt.figure(figsize=(7,7))
plt.scatter(df['sepal width'][:50], df['sepal length'][:50])
plt.xlabel('Sepal Width')
plt.ylabel('Sepal Length')
plt.title('Setosa Sepal Width vs. Length', fontsize=14, y=1.02)
# Out:
# Text(0.5, 1.02, 'Setosa Sepal Width vs. Length')

# %%
y = df['sepal length'][:50]
x = df['sepal width'][:50]
X = sm.add_constant(x)

results = sm.OLS(y, X).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           sepal length   R-squared:                       0.558
# Model:                            OLS   Adj. R-squared:                  0.548
# Method:                 Least Squares   F-statistic:                     60.52
# Date:                Tue, 04 Aug 2020   Prob (F-statistic):           4.75e-10
# Time:                        15:27:11   Log-Likelihood:                 2.0879
# No. Observations:                  50   AIC:                           -0.1759
# Df Residuals:                      48   BIC:                             3.648
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           2.6447      0.305      8.660      0.000       2.031       3.259
# sepal width     0.6909      0.089      7.779      0.000       0.512       0.869
# ==============================================================================
# Omnibus:                        0.252   Durbin-Watson:                   2.517
# Prob(Omnibus):                  0.882   Jarque-Bera (JB):                0.436
# Skew:                          -0.110   Prob(JB):                        0.804
# Kurtosis:                       2.599   Cond. No.                         34.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
plt.figure(figsize=(7,7))
plt.plot(x, results.fittedvalues, label='regression line', color='r')
plt.scatter(x, y, label='data point')
plt.ylabel('Sepal Length')
plt.xlabel('Sepal Width')
plt.title('Setosa Sepal Width vs. Sepal Length', fontsize=14,)
plt.legend(loc=0)

# %% [markdown]
# ### Scikit-Learn

# %%
from sklearn.model_selection import train_test_split as tts

y = df.pop('class')
X_train, X_test, y_train, y_test = tts(df, y, test_size=.3)

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier(max_depth=5, n_estimators=10)

clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

rf = pd.DataFrame(list(zip(y_pred, y_test)), columns=['predicted', 'actual'])
rf['correct'] = rf.apply(lambda x: 1 if x.predicted == x.actual else 0, axis=1)
rf
# Out:
#    predicted actual  correct
# 0        SET    SET        1
# 1        VIR    VIR        1
# 2        VIR    VIR        1
# 3        VIR    VIR        1
# 4        VIR    VIR        1
# 5        VIR    VIR        1
# 6        VER    VER        1
# 7        VIR    VIR        1
# 8        SET    SET        1
# 9        VER    VER        1
# 10       SET    SET        1
# 11       VIR    VIR        1
# 12       SET    SET        1
# 13       SET    SET        1
# 14       VER    VER        1
# 15       VER    VER        1
# 16       VER    VIR        0
# 17       VER    VER        1
# 18       VIR    VIR        1
# 19       SET    SET        1
# 20       VIR    VIR        1
# 21       VER    VER        1
# 22       SET    SET        1
# 23       VIR    VIR        1
# 24       VIR    VIR        1
# 25       VER    VER        1
# 26       SET    SET        1
# 27       SET    SET        1
# 28       SET    SET        1
# 29       SET    SET        1
# 30       VIR    VIR        1
# 31       VER    VER        1
# 32       VER    VER        1
# 33       VER    VER        1
# 34       VER    VER        1
# 35       VER    VER        1
# 36       VIR    VIR        1
# 37       SET    SET        1
# 38       SET    SET        1
# 39       VER    VER        1
# 40       VIR    VIR        1
# 41       VIR    VIR        1
# 42       VER    VER        1
# 43       SET    SET        1
# 44       VIR    VIR        1

# %%
# accuracy percentage

rf['correct'].sum() / rf['correct'].count()
# Out:
# 0.9777777777777777

# %%
# Feature Selection

f_names = df.columns
f_importances = clf.feature_importances_
f_std = np.std([tree.feature_importances_ for tree in clf.estimators_], axis=0)

zz = zip(f_names, f_importances, f_std)
zzs = sorted(zz, key=lambda x: x[1], reverse=True)

labels = [x[0] for x in zzs]
imps = [x[1] for x in zzs]
errs = [x[2] for x in zzs]

plt.figure(figsize=(10,4))
plt.bar(range(df.shape[1]), imps, color='r', yerr=errs, align='center')
plt.xticks(range(df.shape[1]), labels)
# Out:
# ([<matplotlib.axis.XTick at 0x1bca403fca0>,
#   <matplotlib.axis.XTick at 0x1bca403f5b0>,
#   <matplotlib.axis.XTick at 0x1bca402aac0>,
#   <matplotlib.axis.XTick at 0x1bca4078a30>,
#   <matplotlib.axis.XTick at 0x1bca4078f40>,
#   <matplotlib.axis.XTick at 0x1bca4078730>],
#  [Text(0, 0, 'petal area'),
#   Text(1, 0, 'petal width'),
#   Text(2, 0, 'petal length'),
#   Text(3, 0, 'sepal length'),
#   Text(4, 0, 'sepal width'),
#   Text(5, 0, 'wide petal')])

# %%
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC

clf = OneVsRestClassifier(SVC(kernel='linear'))

clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

svc = pd.DataFrame(list(zip(y_pred, y_test)), columns=['predicted', 'actual'])
svc['correct'] = svc.apply(lambda x: 1 if x.predicted == x.actual else 0, axis=1)
svc
# Out:
#    predicted actual  correct
# 0        SET    SET        1
# 1        VIR    VIR        1
# 2        VIR    VIR        1
# 3        VIR    VIR        1
# 4        VIR    VIR        1
# 5        VIR    VIR        1
# 6        VER    VER        1
# 7        VER    VIR        0
# 8        SET    SET        1
# 9        VER    VER        1
# 10       SET    SET        1
# 11       VIR    VIR        1
# 12       SET    SET        1
# 13       SET    SET        1
# 14       VER    VER        1
# 15       VER    VER        1
# 16       VER    VIR        0
# 17       VER    VER        1
# 18       VIR    VIR        1
# 19       SET    SET        1
# 20       VIR    VIR        1
# 21       VER    VER        1
# 22       SET    SET        1
# 23       VIR    VIR        1
# 24       VIR    VIR        1
# 25       VER    VER        1
# 26       SET    SET        1
# 27       SET    SET        1
# 28       SET    SET        1
# 29       SET    SET        1
# 30       VIR    VIR        1
# 31       VER    VER        1
# 32       VER    VER        1
# 33       VER    VER        1
# 34       VER    VER        1
# 35       VER    VER        1
# 36       VIR    VIR        1
# 37       SET    SET        1
# 38       SET    SET        1
# 39       VER    VER        1
# 40       VIR    VIR        1
# 41       VIR    VIR        1
# 42       VER    VER        1
# 43       SET    SET        1
# 44       VIR    VIR        1

# %%
svc['correct'].sum() / svc['correct'].count()
# Out:
# 0.9555555555555556
